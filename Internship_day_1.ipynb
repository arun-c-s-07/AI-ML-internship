# %% [markdown]
# <a href="https://colab.research.google.com/github/arun-c-s-07/AI-ML-internship/blob/main/Internship_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Zudio_sales_data.csv")
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      04-06-2022  ...
# 1            48       404562      Owned      19-12-2020  ...
# 2            97       437773     Rented      04-09-2023  ...
# 3            93       431725      Owned      11-04-2024  ...
# 4            51       415370      Owned      29-05-2022  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  06-11-2024  November      233084
# 1              Alarm    78145  17-06-2024      June      926472
# ...

# %%
df.tail(10)
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7889  Zudio   India  Uttar Pradesh     Madurai     Kids      T-shirts
# 7890  Zudio   India    Maharashtra      Indore     Kids        Shirts
# 7891  Zudio   India     Tamil Nadu       Kochi      Men       Dresses
# 7892  Zudio   India  Uttar Pradesh    Vadodara    Women      Sweaters
# 7893  Zudio   India      Rajasthan   Hyderabad    Women       Jackets
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7889            82       429075     Rented      08-03-2023  ...
# 7890            12       402636     Rented      12-02-2023  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df.dtypes
# Out:
# Store                         object
# Country                       object
# State                         object
# City                          object
# Category                      object
# Clothing Type                 object
# Store Number                   int64
# Postal Code                    int64
# Store Type                    object
# Store Open Date               object
# Selling Area Size (sq ft)      int64
# Store Manager                 object
# Manager ID                    object
# Store Address                 object
# Contact Information           object
# Operating Hours               object
# Staff Count                    int64
# Parking Availability          object
# Security Features             object
# Order ID                       int64
# Order Date                    object
# Month                         object
# Customer ID                    int64
# Customer Name                 object
# Product ID                     int64
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df[['Store Number','City',]]
# Out:
#       Store Number        City
# 0               30       Jalna
# 1               48       Patna
# 2               97     Kolkata
# 3               93     Kolkata
# 4               51    Guwahati
# ...            ...         ...
# 7894            32  Chandigarh
# 7895            52  Aurangabad
# 7896            81        Pune
# 7897            58     Madurai
# 7898            20   Bengaluru
#
# [7899 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv("/content/titanic uncleaned.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['age_mean_imputed']=df['Age'].fillna(df['Age'].mean())
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  age_mean_imputed
# 0   330911   7.8292   NaN        Q              34.5
# 1   363272   7.0000   NaN        S              47.0
# 2   240276   9.6875   NaN        Q              62.0
# 3   315154   8.6625   NaN        S              27.0
# ...

# %%
df['age_median_imputed']=df['Age'].fillna(df['Age'].median())

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  age_mean_imputed  age_median_imputed
# 0   330911   7.8292   NaN        Q              34.5                34.5
# 1   363272   7.0000   NaN        S              47.0                47.0
# 2   240276   9.6875   NaN        Q              62.0                62.0
# ...

# %%
df['age_mode_imputed']=df['Age'].fillna(df['Age'].mode()[0])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  age_mean_imputed  age_median_imputed  \
# 0   330911   7.8292   NaN        Q              34.5                34.5
# 1   363272   7.0000   NaN        S              47.0                47.0
# 2   240276   9.6875   NaN        Q              62.0                62.0
# ...

# %%
df[['Age','age_mean_imputed']]
# Out:
#       Age  age_mean_imputed
# 0    34.5          34.50000
# 1    47.0          47.00000
# 2    62.0          62.00000
# 3    27.0          27.00000
# 4    22.0          22.00000
# ..    ...               ...
# 413   NaN          30.27259
# 414  39.0          39.00000
# 415  38.5          38.50000
# 416   NaN          30.27259
# 417   NaN          30.27259
#
# [418 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.set_style('whitegrid')
sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
# Out:
# /tmp/ipykernel_9859/3010455633.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
plt.figure(figsize=(10,6))
plt.title('box plot of age by passenger class',fontsize=15)
plt.bar(df['Pclass'],df['Age'])
plt.xlabel('passenger class',fontsize=15)
plt.ylabel('age',fontsize=15)

plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Embarked',y='Fare',palette='pastel')
# Out:
# /tmp/ipykernel_9859/812261133.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Embarked',y='Fare',palette='pastel')
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
encoded_data=df.copy()
label_encoder=LabelEncoder()
encoded_data['sex_label']=label_encoder.fit_transform(encoded_data['Sex'])

# %%
one_hot_encoded_data=pd.get_dummies(encoded_data,columns=['Embarked'],prefix=['Embarked'])
encoded_data=pd.concat([encoded_data,one_hot_encoded_data],axis=1)
